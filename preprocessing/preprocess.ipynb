# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("../csi_dataset/csi_labeled_20260209_140928.csv")

print(df.shape)
print(df)
# Out:
# (193, 121)
#      timestamp  label  rssi  noise_floor  channel  fft_gain  agc_gain  \
# 0    351895068      1   -50          -96        6       -38        51
# 1    353796638      1   -50          -96        6       -38        51
# 2    353812444      1   -50          -96        6       -35        50
# 3    353825298      1   -50          -96        6       -35        50
# 4    353838608      1   -50          -96        6       -35        50
# ..         ...    ...   ...          ...      ...       ...       ...
# 188  395651322      0   -45          -96        6       -36        46
# 189  395666038      0   -45          -96        6       -36        46
# 190  395682719      0   -45          -96        6       -36        46
# 191  395696261      0   -45          -96        6       -36        46
# 192  395716853      0   -45          -96        6       -36        46
#
#         amp_0     amp_1     amp_2  ...    amp_104    amp_105    amp_106  \
# 0    5.000000  5.385165  5.099020  ...  29.427877  28.160255  27.658632
# 1    4.123106  5.000000  5.000000  ...  29.017237  27.313000  27.018513
# 2    4.472136  4.000000  5.385165  ...  29.529648  28.844410  28.284271
# 3    4.472136  5.000000  5.385165  ...  30.016663  28.301943  28.442924
# 4    5.000000  5.385165  5.000000  ...  30.479500  29.154760  28.017851
# ..        ...       ...       ...  ...        ...        ...        ...
# 188  3.162278  3.000000  3.162278  ...  61.032776  58.796257  58.600346
# 189  3.162278  3.162278  3.000000  ...  62.000000  60.008335  60.141502
# 190  3.000000  3.000000  3.162278  ...  60.141502  59.236813  60.008331
# 191  3.000000  3.162278  3.162278  ...  59.439045  59.228374  60.000000
# 192  1.414214  3.000000  1.414214  ...  60.000000  59.439045  59.228374
#
#        amp_107    amp_108    amp_109    amp_110    amp_111    amp_112  \
# 0    26.400757  26.000000  24.596748  24.839485  23.769728  23.345236
# 1    25.709921  25.709921  24.207438  24.596748  23.000000  21.931713
# 2    27.202942  26.907249  25.632011  25.079874  24.186775  23.021729
# 3    27.658632  26.400757  25.942244  25.079874  24.351591  23.430748
# 4    26.832817  26.400757  24.738632  25.317976  24.413111  23.323807
# ..         ...        ...        ...        ...        ...        ...
# 188  60.008331  57.384666  57.982754  55.542774  55.000000  53.488316
# 189  60.083275  60.207973  57.706154  56.080299  55.081760  53.235325
# 190  60.415234  58.796257  57.567352  57.218880  54.120239  53.263493
# 191  57.706154  58.077534  56.648033  56.586216  53.488316  53.009434
# 192  58.821762  58.830269  57.558666  56.515484  54.405880  53.338539
#
#        amp_113
# 0    22.472204
# 1    22.022717
# 2    23.345236
# 3    22.847321
# 4    23.194828
# ..         ...
# 188  50.990196
# 189  52.354561
# 190  52.201534
# 191  50.990192
# 192  50.358711
#
# [193 rows x 121 columns]

# %%
amp_cols = [c for c in df.columns if c.startswith("amp_")]
X = df[amp_cols].astype(float)
t = df["timestamp"].astype(float)

# %%
plt.figure()
plt.plot(t, X)  # matplotlib will plot each column as a separate line
plt.xlabel("Time (packet index)")
plt.ylabel("Amplitude")
plt.title("All subcarriers as lines over time (raw)")
plt.show()
